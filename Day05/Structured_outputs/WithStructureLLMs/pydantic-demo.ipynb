# %%
from pydantic import BaseModel

class Student(BaseModel):
    name: str

student1 = Student(name="Kirtan")
print(student1)
# Out:
# name='Kirtan'

# %%
from pydantic import BaseModel

class Student(BaseModel):
    name: str

student2 = Student(name=23)   ## like typedict it gives suggestion but additionally it also raises an error
print(student2)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[2], line 6
#       3 class Student(BaseModel):
#       4     name: str
# ----> 6 student2 = Student(name=23)   ## like typedict it gives suggestion but additionally it also raises an error
#       7 print(student2)
#
# File c:\Users\Ramwani\Desktop\Video Tutorials\venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for Student
# name
#   Input should be a valid string [type=string_type, input_value=23, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type

# %%
from pydantic import BaseModel,EmailStr
from typing import Optional

class Student(BaseModel):
    name: str = "kirtan"  ## default value
    age : Optional[int] = None  ## optional field

student3 = Student()
print(student3.name)
print(student3.age)
# Out:
# kirtan
# None

# %%
from pydantic import BaseModel
from typing import Optional

class Student(BaseModel):
    name: str = "kirtan"  ## default value
    age : Optional[int] = None  ## optional field

student3 = Student(age = "32") ## type coercion
print(student3.name)
print(student3.age)
# Out:
# kirtan
# 32

# %%
from pydantic import BaseModel,EmailStr
from typing import Optional

class Student(BaseModel):
    name: str = "kirtan"  ## default value
    age : Optional[int] = None  ## optional field
    email : EmailStr

student3 = Student(email = "kirtan@gmail.com")   ## valid email
print(student3.name)
print(student3.age)
print(student3.email)
# Out:
# kirtan
# None
# kirtan@gmail.com
